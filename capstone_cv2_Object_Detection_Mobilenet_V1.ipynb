# %%
# %tensorflow_version 1.15
import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7411 sha256=154af07040c9ef6cfa54b01ec9aeb9396d46d84023c12d8da704a2898005669a
#   Stored in directory: /root/.cache/pip/wheels/6e/f8/83/534c52482d6da64622ddbf72cd93c35d2ef2881b78fd08ff0c
# Successfully built gputil
# ...
# Gen RAM Free: 26.1 GB  | Proc size: 521.7 MB
# GPU RAM Free: 16023MB | Used: 257MB | Util   2% | Total 16280MB

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change to working tensorflow directory on the drive
# %cd '/content/gdrive/My Drive/tfmodels/'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/tfmodels

# %%
#pip install tf-models-official

# %%
import sys
sys.path.append("/content/gdrive/My Drive/tfmodels/models")

# %%
#pip install tensorflow.io

# %%
# !pip install tf_slim
# Out:
# ...
#      |████████████████████████████████| 352 kB 7.4 MB/s
# ...

# %%
#!git clone https://github.com/tensorflow/models.git

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,614 kB of archives.
# After this operation, 8,908 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
# !pip install Cython

# %%
# %cd /content/gdrive/My Drive/tfmodels/models/research/
# Out:
# /content/gdrive/My Drive/tfmodels/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/tfmodels/models/research/:/content/gdrive/My Drive/tfmodels/models/research/slim'

# %%
# !python object_detection/builders/model_builder_test.py

# %%
import numpy as np
import pandas as pd
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from object_detection.utils import dataset_util
from collections import namedtuple, OrderedDict
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util
import cv2

# %%
#xml_df = pd.read_csv("/content/gdrive/My Drive/capstone/df_tr.csv",names=['filename','xmin','ymin','xmax','ymax','class','height','width','image_path'])

# %%
#xml_df.sample()
# Out:
#        filename  xmin  ... width                                         image_path
# 9782  05188.jpg  28.0  ...   480  /content/drive/My Drive/capstone/Dataset/Car I...
#
# [1 rows x 9 columns]

# %%
#xml_df = xml_df[['filename','width','height','class','xmin','ymin','xmax','ymax']]
#xml_df

# %%
#xml_df.drop([xml_df.index[0]],inplace=True)
#xml_df.reset_index(inplace=True,drop=True)
#xml_df

# %%
#xml_df_test = pd.read_csv("/content/gdrive/My Drive/capstone/df_ts.csv",names=['filename','xmin','ymin','xmax','ymax','class','height','width','image_path'])
#xml_df_test

# %%
#xml_df_test = xml_df_test[['filename','width','height','class','xmin','ymin','xmax','ymax']]

# %%
#xml_df_test.drop([xml_df_test.index[0]],inplace=True)
#xml_df_test.reset_index(inplace=True,drop=True)
#xml_df_test

# %%
# %cd /content/gdrive/My Drive/tfmodels/models/research/object_detection/data
# Out:
# /content/gdrive/My Drive/tfmodels/models/research/object_detection/data

# %%
#xml_df.to_csv('{}_labels.csv'.format('train'), index=None)
#xml_df_test.to_csv('{}_labels.csv'.format('test'), index=None)

# %%
# %cd /content/gdrive/My Drive/tfmodels/models/research/object_detection/
# Out:
# /content/gdrive/My Drive/tfmodels/models/research/object_detection

# %%
#!python generate_tfrecord.py --csv_input=data/train_labels.csv  --output_path=data/train.record --image_dir=images/train/

# %%
#!python generate_tfrecord.py --csv_input=data/test_labels.csv  --output_path=data/test.record --image_dir=images/test/

# %%
# %cd /content/gdrive/My Drive/tfmodels/models/research/object_detection
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/models/research/:/content/gdrive/My Drive/Tensorflow/models/research/slim'
# Out:
# /content/gdrive/My Drive/tfmodels/models/research/object_detection

# %%
# !python train.py --train_dir=training/ --pipeline_config_path=training/ssd_mobilenet_v1_pets.config --logtostderr
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:global step 17505: loss = 4.1624 (0.474 sec/step)
# I1214 14:31:19.888398 139820614760320 learning.py:512] global step 17505: loss = 4.1624 (0.474 sec/step)
# INFO:tensorflow:global step 17506: loss = 3.2177 (0.392 sec/step)
# I1214 14:31:20.281418 139820614760320 learning.py:512] global step 17506: loss = 3.2177 (0.392 sec/step)
# INFO:tensorflow:global step 17507: loss = 3.2126 (0.343 sec/step)
# I1214 14:31:20.626099 139820614760320 learning.py:512] global step 17507: loss = 3.2126 (0.343 sec/step)
# INFO:tensorflow:global step 17508: loss = 5.0547 (0.496 sec/step)
# I1214 14:31:21.123650 139820614760320 learning.py:512] global step 17508: loss = 5.0547 (0.496 sec/step)
# INFO:tensorflow:global step 17509: loss = 3.5291 (0.599 sec/step)
# I1214 14:31:21.723737 139820614760320 learning.py:512] global step 17509: loss = 3.5291 (0.599 sec/step)
# INFO:tensorflow:global step 17510: loss = 3.7129 (0.338 sec/step)
# ...

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/ssd_mobilenet_v1_pets.config --trained_checkpoint_prefix training/model.ckpt-19411 --output_directory new_graph
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1214 14:59:23.861610 140468125181824 deprecation.py:323] From /usr/local/lib/python3.7/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1214 14:59:25.206640 140468125181824 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1214 14:59:25.243204 140468125181824 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# ...

# %%
# !zip -r model_graph.zip new_graph
# Out:
#   adding: new_graph/ (stored 0%)
#   adding: new_graph/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: new_graph/model.ckpt.index (deflated 67%)
#   adding: new_graph/checkpoint (deflated 42%)
#   adding: new_graph/model.ckpt.meta (deflated 95%)
#   adding: new_graph/frozen_inference_graph.pb (deflated 16%)
#   adding: new_graph/saved_model/ (stored 0%)
#   adding: new_graph/saved_model/variables/ (stored 0%)
#   adding: new_graph/saved_model/saved_model.pb (deflated 17%)
#   adding: new_graph/pipeline.config (deflated 69%)

# %%
# !python predict_images.py
# Out:
# WARNING:tensorflow:From predict_images.py:63: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From predict_images.py:64: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From predict_images.py:109: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-12-14 16:48:49.699330: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-12-14 16:48:49.703292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-14 16:48:49.703848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# ...
